# %%
# Import and load the spacy model
import spacy
nlp=spacy.load("en_core_web_sm") 

# Getting the ner component
ner=nlp.get_pipe('ner')

# %%
LABEL = "Traffic"
TRAIN_DATA =[("n this connection, it is high time not just to talk but to do something about staggered hours and getting rid of the rush hour",{"entities":[(117,126,"Traffic")]}),
("At the peak rush hour, many people will get on at the terminus, but many will get off at the intermediate stations.",{"entities":[(11,21,"Traffic")]}),
(" traffic congestion, closed streets because of an event, discomfort for residents.",{"entities":[(1,19,"Traffic")]}),
(" The increasing population has resulted in an increase in traffic congestion ",{"entities":[(58,76,"Traffic")]}),
("Expect traffic congestion in these areas and plan ahead.",{"entities":[(6,25,"Traffic")]}),
("The trafffic congestion caused by the street closure was immense",{"entities":[(3,23,"Traffic")]}),
("Fuel efficiencies similarly were much worse with traffic congestion",{"entities":[(49,67,"Traffic")]}),
("In that case he will be aware, should he travel at rush hourr, that the overcrowding is obscene",{"entities":[(51,61,"Traffic")]}),
("That is a different concept from the rsh hour when the buses are packed",{"entities":[(36,45,"Traffic")]}),
("If one drives at 70 mph during the rush hour, one is almost the only person doing so.",{"entities":[(34,44,"Traffic")]}),
("The problems occur not just in the rush hour but for much of the working day.",{"entities":[(35,44,"Traffic")]}),
("Many of the people who work in those offices have a long journey in the rush hur for a considerable distance",{"entities":[(72,80,"Traffic")]}),
("They would want to use it during the rush hour.",{"entities":[(36,46,"Traffic")]}),
("That is not unusual in the rush hour when such accidents can occur.",{"entities":[(27,36,"Traffic")]}),
("At every period throughout that rush hour there would still be a considerable number of people standing in those trains.",{"entities":[(32,41,"Traffic")]}),
("In the rush hour, it takes 40 minutes to do so and at other times it takes 25 minutes.",{"entities":[(6,16,"Traffic")]}),
(" I was stuck in a traffic jm for an hour yesterday.",{"entities":[(17,28,"Traffic")]}),
("if the roadblock suddenly clears, tap Recalculate route to replan your original route.",{"entities":[(7,17,"Traffic")]}),
("Within weeks, a new roadblock appeared in the form of Arizona State Senator kimberly Yee.",{"entities":[(20,30,"Traffic")]}),
("This is a HUGE roadblock and if the two of you don't work on that issue, nothing you do to light a fire in your marriage will last for long",{"entities":[(15,25,"Traffic")]}),
("We lost our way when we discovered a police roadblock.",{"entities":[(44,53,"Traffic")]}),
(" Sorry were late. We got stuck in a traffic jam",{"entities":[(36,47,"Traffic")]}),
("Action against traffic congestion in urban area",{"entities":[(15,33,"Traffic")]}),
("There are cues that signify congestion",{"entities":[(28,38,"Traffic")]}),
(" Reducing congestion around major airports would also cut emissions",{"entities":[(10,21,"Traffic")]}),
("New measures have been introduced to try and ease traffic congestion in the city",{"entities":[(50,68,"Traffic")]}),
("Traffic congestion in large cities seems to be an insoluble problem",{"entities":[(0,19,"Traffic")]}),
("The congestion in the city gets even worse during the summer",{"entities":[(4,15,"Traffic")]}),
("Urban regeneration brings congestion by the lorry load A 44 ton refrigerated lorry is blocking the road ahead.",{"entities":[(26,37,"Traffic")]}),
("The plans are part of the Council 's ongoing efforts to tackle congestion.",{"entities":[(63,73,"Traffic")]}),
("The traffic causes serious disturbance to residents",{"entities":[(4,11,"Traffic")]}),
("The noisy traffic is a continual annoyance to the citizens",{"entities":[(10,18,"Traffic")]}),
("Residents are complaining because traffic in the area has increased",{"entities":[(34,42,"Traffic")]}),
(". The snow had a predictable effect on trffic",{"entities":[(39,45,"Traffic")]}),
("Traffic is backed up for 5 miles due to a bad accident on the highway",{"entities":[(0,8,"Traffic")]}),
("Of trespassers the number killed per mile of line is about as large in England as in America, the density of population and of traffc in Great Britain apparently counterbalancing the laxity of the laws against trespassing in America",{"entities":[(127,134,"Traffic")]}),
("It would be nice getting away from the smog and traffic for a while.",{"entities":[(48,56,"Traffic")]}),
("There was heavy trafic on the roads",{"entities":[(16,23,"Traffic")]}),
("There was heavy traffic on the roads",{"entities":[(16,24,"Traffic")]}),
("Their central control headquarters are immediately informed when a traffic jam takes place",{"entities":[(67,78,"Traffic")]}),
("This road now carries an immense number of container vehicles and has become a monumental traffic jam most of the year round.",{"entities":[(89,102,"Traffic")]}),
("I am instituting careful monitoring of incidents causing, or likely to cause, a traffic jam on the bridge.",{"entities":[(80,91,"Traffic")]}),
("It is extraordinary that people seem to think that there is an advantage to be gained from sitting in a traffic jam",{"entities":[(104,115,"Traffic")]}),
("Last summer we had one traffic jam in which the traffic lined up right back through the tunnel.",{"entities":[(23,34,"Traffic"),(48,56,"Traffic")]}),
("It is terrible to be stuck in a traffic jam",{"entities":[(32,43,"Traffic")]}),
("It can take two hours to reach a hospital when one is travelling through a solid traffic jam",{"entities":[(81,92,"Traffic")]}),
("Anybody who has been stuck in a traffic jam for 10 or 15 minutes must resent the waste of time.",{"entities":[(31,43,"Traffic")]}),
("Traffic was lightnonexistent by eastern standardsmade up mostly of Jeeps or pickup trucks, the latter with a dog pacing the back bed in perfect balance.",{"entities":[(0,8,"Traffic")]}),
("Even on this holiday, one of the busiest days of the year, traffic remained modest by urban standards.",{"entities":[(59,67,"Traffic")]}),]

# %%
# Add the new label to ner
ner.add_label(LABEL)

# Resume training
optimizer = nlp.resume_training()
move_names = list(ner.move_names)

# List of pipes you want to train
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]

# List of pipes which should remain unaffected in training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# %%
# Importing requirements
from spacy.util import minibatch, compounding
from spacy.training import Example

import random

# Begin training by disabling other pipeline components
with nlp.disable_pipes(*other_pipes) :

  sizes = compounding(1.0, 4.0, 1.001)
  # Training for 30 iterations     
  for itn in range(30):
    # shuffle examples before training
    random.shuffle(TRAIN_DATA)
    # batch up the examples using spaCy's minibatch
    batches = minibatch(TRAIN_DATA, size=sizes)
    # ictionary to store losses
    losses = {}
    for batch in batches:
      texts, annotations = zip(*batch)
      # Calling update() over the iteration
      example = []
            # Update the model with iterating each text
      for i in range(len(texts)):
        doc = nlp.make_doc(texts[i])
        example.append(Example.from_dict(doc, annotations[i]))

        # Update the model
      nlp.update(example, drop=0.5, losses=losses)
      print("Losses", losses)
# Out:
# D:\Software\Anaconda\lib\site-packages\spacy\training\iob_utils.py:141: UserWarning: [W030] Some entities could not be aligned in the text "There was heavy traffic on the roads" with entities "[(16, 24, 'Traffic')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses {'ner': 0.00010825738205413917}
# Losses {'ner': 1.3549938322196113}
# D:\Software\Anaconda\lib\site-packages\spacy\training\iob_utils.py:141: UserWarning: [W030] Some entities could not be aligned in the text "It would be nice getting away from the smog and tr..." with entities "[(48, 56, 'Traffic')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses {'ner': 1.3550940354609897}
# Losses {'ner': 3.182008763172856}
# ...

# %%
test_text = 'I stucked In Traffic'
doc = nlp(test_text)
from spacy import displacy
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the streets are busy with cars</div></span>
